# %%
import numpy as np
import pandas as pd

# %%
dat = pd.read_csv("bgg_dataset_raw.csv", delimiter=";").dropna().reset_index()
dat.shape
# Out:
# (9709, 15)

# %%
dat.columns = dat.columns.str.lower().str.replace(" ", "_", regex=True)
dat = dat.astype({
    "id": "int64",
    "year_published": "int64",
    "owned_users": "int64",
})
dat["rating_average"] = dat["rating_average"].str.replace(",", ".").astype(float)
dat["complexity_average"] = dat["complexity_average"].str.replace(",", ".").astype(float)

domains_split = dat["domains"].str.split(", ", expand=True)
domains_split.columns = [f"domains{i+1}" for i in range(domains_split.shape[1])]

dat = pd.concat([dat, mechanics_split, domains_split], axis=1)

dat = dat.drop(['mechanics', 'domains2', 'domains3'], axis=1)

# %%
dat = dat[(dat["max_players"] <= 30) & 
          (dat["max_players"] > 0) & 
          (dat["min_players"] > 0) & 
          (dat["min_players"] <= dat["max_players"])]

print(dat.shape)

dat = dat[(dat["name"].str.count("-") <= 1) & 
          (dat["name"].str.count("&") <= 1) & 
          (dat["name"].str.split().str.len() <= 10)]

print(dat.shape)

dat = dat[(dat["play_time"] > 0) & 
          (dat["play_time"] <= 360)]

print(dat.shape)
# Out:
# (9597, 37)
# (9396, 37)
# (8965, 37)

# %%
dat
# Out:
#       index      id                          name  year_published  \
# 0         0  174430                    Gloomhaven            2017
# 1         1  161936     Pandemic Legacy: Season 1            2015
# 2         2  224517             Brass: Birmingham            2018
# 3         3  167791             Terraforming Mars            2016
# 5         5  291457  Gloomhaven: Jaws of the Lion            2020
# ...     ...     ...                           ...             ...
# 9702  20335    1406                      Monopoly            1933
# 9703  20336    2921              The Game of Life            1960
# 9704  20337    1410                       Trouble            1965
# 9706  20340    5048                    Candy Land            1949
# 9707  20341    5432            Chutes and Ladders            -200
#
#       min_players  max_players  play_time  min_age  users_rated  \
# 0               1            4        120       14        42055
# 1               2            4         60       13        41643
# 2               2            4        120       14        19217
# 3               1            5        120       12        64864
# 5               1            4        120       14         8392
# ...           ...          ...        ...      ...          ...
# 9702            2            8        180        8        28999
# 9703            2            6         60        8        10658
# 9704            2            4         45        4         3255
# 9706            2            4         30        3         4006
# 9707            2            6         30        3         3783
#
#       rating_average  ...                         mechanics13  \
# 0               8.79  ...                       Modular Board
# 1               8.61  ...                                None
# 2               8.66  ...                                None
# 3               8.43  ...                                None
# 5               8.87  ...  Scenario / Mission / Campaign Game
# ...              ...  ...                                 ...
# 9702            4.39  ...                                None
# 9703            4.30  ...                                None
# 9704            3.79  ...                                None
# 9706            3.18  ...                                None
# 9707            2.86  ...                                None
#
#                         mechanics14                         mechanics15  \
# 0           Once-Per-Game Abilities  Scenario / Mission / Campaign Game
# 1                              None                                None
# 2                              None                                None
# 3                              None                                None
# 5     Simultaneous Action Selection               Solo / Solitaire Game
# ...                             ...                                 ...
# 9702                           None                                None
# 9703                           None                                None
# 9704                           None                                None
# 9706                           None                                None
# 9707                           None                                None
#
#                         mechanics16            mechanics17   mechanics18  \
# 0     Simultaneous Action Selection  Solo / Solitaire Game  Storytelling
# 1                              None                   None          None
# 2                              None                   None          None
# 3                              None                   None          None
# 5            Variable Player Powers                   None          None
# ...                             ...                    ...           ...
# 9702                           None                   None          None
# 9703                           None                   None          None
# 9704                           None                   None          None
# 9706                           None                   None          None
# 9707                           None                   None          None
#
#                  mechanics19          domains1        domains2 domains3
# 0     Variable Player Powers    Strategy Games  Thematic Games     None
# 1                       None    Strategy Games  Thematic Games     None
# 2                       None    Strategy Games            None     None
# 3                       None    Strategy Games            None     None
# 5                       None    Strategy Games  Thematic Games     None
# ...                      ...               ...             ...      ...
# 9702                    None      Family Games            None     None
# 9703                    None      Family Games            None     None
# 9704                    None  Children's Games            None     None
# 9706                    None  Children's Games            None     None
# 9707                    None  Children's Games            None     None
#
# [8965 rows x 37 columns]

# %%
dat.columns
# Out:
# Index(['index', 'id', 'name', 'year_published', 'min_players', 'max_players',
#        'play_time', 'min_age', 'users_rated', 'rating_average', 'bgg_rank',
#        'complexity_average', 'owned_users', 'mechanics', 'domains',
#        'mechanics1', 'mechanics2', 'mechanics3', 'mechanics4', 'mechanics5',
#        'mechanics6', 'mechanics7', 'mechanics8', 'mechanics9', 'mechanics10',
#        'mechanics11', 'mechanics12', 'mechanics13', 'mechanics14',
#        'mechanics15', 'mechanics16', 'mechanics17', 'mechanics18',
#        'mechanics19', 'domains1', 'domains2', 'domains3'],
#       dtype='object')

# %%
dat.to_json("bgg_dataset_cleaned.json", orient="records", indent=4)
dat.to_json("src/bgg_dataset_cleaned.json", orient="records", indent=4)
