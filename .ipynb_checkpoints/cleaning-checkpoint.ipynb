# %%
import numpy as np
import pandas as pd

# %%
dat = pd.read_csv("bgg_dataset_raw.csv", delimiter=";").dropna().reset_index()
dat.head()
# Out:
#    index        ID                               Name  Year Published  \
# 0      0  174430.0                         Gloomhaven          2017.0
# 1      1  161936.0          Pandemic Legacy: Season 1          2015.0
# 2      2  224517.0                  Brass: Birmingham          2018.0
# 3      3  167791.0                  Terraforming Mars          2016.0
# 4      4  233078.0  Twilight Imperium: Fourth Edition          2017.0
#
#    Min Players  Max Players  Play Time  Min Age  Users Rated Rating Average  \
# 0            1            4        120       14        42055           8,79
# 1            2            4         60       13        41643           8,61
# 2            2            4        120       14        19217           8,66
# 3            1            5        120       12        64864           8,43
# 4            3            6        480       14        13468           8,70
#
#    BGG Rank Complexity Average  Owned Users  \
# 0         1               3,86      68323.0
# 1         2               2,84      65294.0
# 2         3               3,91      28785.0
# 3         4               3,24      87099.0
# 4         5               4,22      16831.0
#
#                                            Mechanics  \
# 0  Action Queue, Action Retrieval, Campaign / Bat...
# 1  Action Points, Cooperative Game, Hand Manageme...
# 2  Hand Management, Income, Loans, Market, Networ...
# 3  Card Drafting, Drafting, End Game Bonuses, Han...
# 4  Action Drafting, Area Majority / Influence, Ar...
#
#                           Domains
# 0  Strategy Games, Thematic Games
# 1  Strategy Games, Thematic Games
# 2                  Strategy Games
# 3                  Strategy Games
# 4  Strategy Games, Thematic Games

# %%
dat.columns = dat.columns.str.lower().str.replace(" ", "_", regex=True)
dat = dat.astype({
    "id": "int64",
    "year_published": "int64",
    "owned_users": "int64",
})
dat["rating_average"] = dat["rating_average"].str.replace(",", ".").astype(float)
dat["complexity_average"] = dat["complexity_average"].str.replace(",", ".").astype(float)

mechanics_split = dat["mechanics"].str.split(", ", expand=True)
mechanics_split.columns = [f"mechanics{i+1}" for i in range(mechanics_split.shape[1])]

domains_split = dat["domains"].str.split(", ", expand=True)
domains_split.columns = [f"domains{i+1}" for i in range(domains_split.shape[1])]

dat = pd.concat([dat, mechanics_split, domains_split], axis=1)

# %%
dat.head()
# Out:
#    index      id                               name  year_published  \
# 0      0  174430                         Gloomhaven            2017
# 1      1  161936          Pandemic Legacy: Season 1            2015
# 2      2  224517                  Brass: Birmingham            2018
# 3      3  167791                  Terraforming Mars            2016
# 4      4  233078  Twilight Imperium: Fourth Edition            2017
#
#    min_players  max_players  play_time  min_age  users_rated  rating_average  \
# 0            1            4        120       14        42055            8.79
# 1            2            4         60       13        41643            8.61
# 2            2            4        120       14        19217            8.66
# 3            1            5        120       12        64864            8.43
# 4            3            6        480       14        13468            8.70
#
#    ...    mechanics13              mechanics14  \
# 0  ...  Modular Board  Once-Per-Game Abilities
# 1  ...           None                     None
# 2  ...           None                     None
# 3  ...           None                     None
# 4  ...           None                     None
#
#                           mechanics15                    mechanics16  \
# 0  Scenario / Mission / Campaign Game  Simultaneous Action Selection
# 1                                None                           None
# 2                                None                           None
# 3                                None                           None
# 4                                None                           None
#
#              mechanics17   mechanics18             mechanics19  \
# 0  Solo / Solitaire Game  Storytelling  Variable Player Powers
# 1                   None          None                    None
# 2                   None          None                    None
# 3                   None          None                    None
# 4                   None          None                    None
#
#          domains1        domains2 domains3
# 0  Strategy Games  Thematic Games     None
# 1  Strategy Games  Thematic Games     None
# 2  Strategy Games            None     None
# 3  Strategy Games            None     None
# 4  Strategy Games  Thematic Games     None
#
# [5 rows x 37 columns]

# %%
dat.columns
# Out:
# Index(['index', 'id', 'name', 'year_published', 'min_players', 'max_players',
#        'play_time', 'min_age', 'users_rated', 'rating_average', 'bgg_rank',
#        'complexity_average', 'owned_users', 'mechanics', 'domains',
#        'mechanics1', 'mechanics2', 'mechanics3', 'mechanics4', 'mechanics5',
#        'mechanics6', 'mechanics7', 'mechanics8', 'mechanics9', 'mechanics10',
#        'mechanics11', 'mechanics12', 'mechanics13', 'mechanics14',
#        'mechanics15', 'mechanics16', 'mechanics17', 'mechanics18',
#        'mechanics19', 'domains1', 'domains2', 'domains3'],
#       dtype='object')

# %%
dat.to_json("bgg_dataset_cleaned.json", orient="records", indent=4)
