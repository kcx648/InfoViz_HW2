# %%
import numpy as np
import pandas as pd

# %%
dat = pd.read_csv("bgg_dataset_raw.csv", delimiter=";").dropna().reset_index()
dat.shape
# Out:
# (9709, 15)

# %%
dat.columns = dat.columns.str.lower().str.replace(" ", "_", regex=True)
dat = dat.astype({
    "id": "int64",
    "year_published": "int64",
    "owned_users": "int64",
})
dat["rating_average"] = dat["rating_average"].str.replace(",", ".").astype(float)
dat["complexity_average"] = dat["complexity_average"].str.replace(",", ".").astype(float)

domains_split = dat["domains"].str.split(", ", expand=True)
domains_split.columns = [f"domains{i+1}" for i in range(domains_split.shape[1])]

dat = pd.concat([dat, domains_split], axis=1)

dat = dat.drop(['mechanics', 'domains2', 'domains3', 'domains', 'bgg_rank', 'users_rated'], axis=1)

# %%
dat = dat[(dat["max_players"] <= 30) & 
          (dat["max_players"] > 0) & 
          (dat["min_players"] > 0) & 
          (dat["min_players"] <= dat["max_players"])]

print(dat.shape)

dat = dat[(dat["name"].str.count("-") <= 1) & 
          (dat["name"].str.count("&") <= 1) & 
          (dat["name"].str.split().str.len() <= 10)]

print(dat.shape)

dat = dat[(dat["play_time"] > 0) & 
          (dat["play_time"] <= 360)]

print(dat.shape)
# Out:
# (9597, 14)
# (9396, 14)
# (8965, 14)

# %%
dat
# Out:
#       index      id                          name  year_published  \
# 0         0  174430                    Gloomhaven            2017
# 1         1  161936     Pandemic Legacy: Season 1            2015
# 2         2  224517             Brass: Birmingham            2018
# 3         3  167791             Terraforming Mars            2016
# 5         5  291457  Gloomhaven: Jaws of the Lion            2020
# ...     ...     ...                           ...             ...
# 9702  20335    1406                      Monopoly            1933
# 9703  20336    2921              The Game of Life            1960
# 9704  20337    1410                       Trouble            1965
# 9706  20340    5048                    Candy Land            1949
# 9707  20341    5432            Chutes and Ladders            -200
#
#       min_players  max_players  play_time  min_age  users_rated  \
# 0               1            4        120       14        42055
# 1               2            4         60       13        41643
# 2               2            4        120       14        19217
# 3               1            5        120       12        64864
# 5               1            4        120       14         8392
# ...           ...          ...        ...      ...          ...
# 9702            2            8        180        8        28999
# 9703            2            6         60        8        10658
# 9704            2            4         45        4         3255
# 9706            2            4         30        3         4006
# 9707            2            6         30        3         3783
#
#       rating_average  bgg_rank  complexity_average  owned_users  \
# 0               8.79         1                3.86        68323
# 1               8.61         2                2.84        65294
# 2               8.66         3                3.91        28785
# 3               8.43         4                3.24        87099
# 5               8.87         6                3.55        21609
# ...              ...       ...                 ...          ...
# 9702            4.39     20337                1.65        40255
# 9703            4.30     20338                1.18        16692
# 9704            3.79     20339                1.05         4962
# 9706            3.18     20342                1.08         5788
# 9707            2.86     20343                1.02         4400
#
#               domains1
# 0       Strategy Games
# 1       Strategy Games
# 2       Strategy Games
# 3       Strategy Games
# 5       Strategy Games
# ...                ...
# 9702      Family Games
# 9703      Family Games
# 9704  Children's Games
# 9706  Children's Games
# 9707  Children's Games
#
# [8965 rows x 14 columns]

# %%
dat.columns
# Out:
# Index(['index', 'id', 'name', 'year_published', 'min_players', 'max_players',
#        'play_time', 'min_age', 'users_rated', 'rating_average', 'bgg_rank',
#        'complexity_average', 'owned_users', 'domains1'],
#       dtype='object')

# %%
np.max(dat["year_published"])
# Out:
# 2021

# %%
dat.to_json("bgg_dataset_cleaned.json", orient="records", indent=4)
dat.to_json("src/bgg_dataset_cleaned.json", orient="records", indent=4)

# %%
dat[dat["name"].str.len() == max(dat["name"].str.len())]
# Out:
#       index      id                                               name  \
# 4331   5278  120265  Supply Lines of the American Revolution: The N...
#
#       year_published  min_players  max_players  play_time  min_age  \
# 4331            2017            2            2        180        0
#
#       users_rated  rating_average  bgg_rank  complexity_average  owned_users  \
# 4331          151            7.59      5280                 2.7          530
#
#       domains1
# 4331  Wargames

# %%
max(dat["min_age"])
# Out:
# 21
